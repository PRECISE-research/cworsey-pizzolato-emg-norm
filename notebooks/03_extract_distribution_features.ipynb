# %% [markdown]
# # Extract variance and KDE FWHM

# %%
from pathlib import Path
ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
TRIAL = ROOT / 'examples/full_trial_data/C06/trial_ffc10db23f/emgBPF.mot'

# %%
from emg_normalisation.calibration import removeGain
from emg_normalisation.features import extract_window_features
from emg_normalisation.io import read_emg_mot
from emg_normalisation.preprocessing import infer_sampling_rate
frame = removeGain(read_emg_mot(TRIAL), amplifier_gain=1000)
features = extract_window_features(frame['r_vaslat'], infer_sampling_rate(frame['time']))
features.as_matrix()[:5]
