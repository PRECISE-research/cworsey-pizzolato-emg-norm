# %% [markdown]
# # Load and plot bandpass EMG

# %%
from pathlib import Path
ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
TRIAL = ROOT / 'examples/full_trial_data/C06/trial_ffc10db23f/emgBPF.mot'

# %%
import matplotlib.pyplot as plt
from emg_normalisation.io import read_emg_mot
frame = read_emg_mot(TRIAL)
frame.plot(x='time', y='r_vaslat', legend=False)
plt.ylabel('Stored EMG (V)'); plt.show()
