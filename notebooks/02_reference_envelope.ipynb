# %% [markdown]
# # Generate a conventional reference envelope

# %%
from pathlib import Path
ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
TRIAL = ROOT / 'examples/full_trial_data/C06/trial_ffc10db23f/emgBPF.mot'

# %%
from emg_normalisation.calibration import removeGain
from emg_normalisation.io import read_emg_mot
from emg_normalisation.preprocessing import conventional_linear_envelope
bandpass_mV = removeGain(read_emg_mot(TRIAL), amplifier_gain=1000)
envelope = conventional_linear_envelope(bandpass_mV)
envelope.head()
